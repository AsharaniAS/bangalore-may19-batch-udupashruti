# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
import tensorflow as tf
tf.random.set_seed(42)

# %%
tf.__version__
# Out:
# '2.0.0'

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))

# %%
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
model.add(tf.keras.layers.Dense(200, activation='relu'))

# %%
model.add(tf.keras.layers.Dense(100, activation='relu'))

# %%
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, verbose=1, mode='auto')
callback_list = [early_stopping]

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# dense_8 (Dense)              (None, 200)               157000
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 181,246
# Trainable params: 179,678
# Non-trainable params: 1,568
# _________________________________________________________________

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=25,batch_size=32,callbacks=callback_list)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/25
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.5121 - accuracy: 0.8175 - val_loss: 0.3869 - val_accuracy: 0.8597
# Epoch 2/25
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.3965 - accuracy: 0.8545 - val_loss: 0.3979 - val_accuracy: 0.8566
# Epoch 3/25
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3588 - accuracy: 0.8700 - val_loss: 0.3720 - val_accuracy: 0.8669
# Epoch 4/25
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.3367 - accuracy: 0.8764 - val_loss: 0.3602 - val_accuracy: 0.8743
# Epoch 5/25
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.3157 - accuracy: 0.8823 - val_loss: 0.3440 - val_accuracy: 0.8776
# Epoch 6/25
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2975 - accuracy: 0.8886 - val_loss: 0.3530 - val_accuracy: 0.8778
# Epoch 7/25
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.2843 - accuracy: 0.8934 - val_loss: 0.3781 - val_accuracy: 0.8813
# Epoch 8/25
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.2756 - accuracy: 0.8975 - val_loss: 0.3379 - val_accuracy: 0.8853
# Epoch 9/25
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.2650 - accuracy: 0.9010 - val_loss: 0.3709 - val_accuracy: 0.8811
# Epoch 10/25
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.2537 - accuracy: 0.9044 - val_loss: 0.3741 - val_accuracy: 0.8871
# Epoch 11/25
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2505 - accuracy: 0.9057 - val_loss: 0.3648 - val_accuracy: 0.8826
# Epoch 12/25
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.2382 - accuracy: 0.9092 - val_loss: 0.3690 - val_accuracy: 0.8870
# Epoch 13/25
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.2316 - accuracy: 0.9123 - val_loss: 0.4791 - val_accuracy: 0.8857
# Epoch 14/25
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2240 - accuracy: 0.9146 - val_loss: 0.4166 - val_accuracy: 0.8885
# Epoch 15/25
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2172 - accuracy: 0.9179 - val_loss: 0.4045 - val_accuracy: 0.8836
# Epoch 16/25
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2144 - accuracy: 0.9189 - val_loss: 0.4110 - val_accuracy: 0.8906
# Epoch 17/25
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2050 - accuracy: 0.9218 - val_loss: 0.5410 - val_accuracy: 0.8901
# Epoch 18/25
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.2007 - accuracy: 0.9226 - val_loss: 0.4422 - val_accuracy: 0.8886
# Epoch 19/25
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.1985 - accuracy: 0.9245 - val_loss: 0.4194 - val_accuracy: 0.8914
# Epoch 20/25
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.1929 - accuracy: 0.9263 - val_loss: 0.4788 - val_accuracy: 0.8863
# Epoch 21/25
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.1908 - accuracy: 0.9287 - val_loss: 0.4331 - val_accuracy: 0.8912
# Epoch 22/25
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.1848 - accuracy: 0.9292 - val_loss: 0.4237 - val_accuracy: 0.8894
# Epoch 23/25
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.1839 - accuracy: 0.9291 - val_loss: 0.4473 - val_accuracy: 0.8858
# Epoch 24/25
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.1766 - accuracy: 0.9317 - val_loss: 0.4821 - val_accuracy: 0.8916
# Epoch 25/25
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.1756 - accuracy: 0.9338 - val_loss: 0.4698 - val_accuracy: 0.8924

# %%
loss_and_metrics = model.evaluate(x_test, y_test)
print(loss_and_metrics)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.4698296595335007, 0.8924]
